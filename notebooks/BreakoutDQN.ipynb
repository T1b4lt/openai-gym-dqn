# %%
import gym
from gym.wrappers import Monitor
from collections import deque
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import math
import time
import glob
import io
import base64
import cv2
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 
from IPython.display import HTML
from IPython import display as ipythondisplay

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# 2022-03-02 20:18:15.753181: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/cxb0439/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-03-02 20:18:15.753207: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# TRAINING
MAX_STEPS_PER_EPISODE = 10000
REWARD_TASK_SOLVED = 40

# AGENT HYPERPARAMETERS
LEARNING_RATE = 0.0001
DISCOUNT_FACTOR = 0.99
EXPLORATION_RATIO = 1.0
E_DECAY_LIMIT = 0.05
EXPLORATION_RATIO_INTERVAL = EXPLORATION_RATIO - E_DECAY_LIMIT
BATCH_SIZE = 64
MEM_BUFFER = 100000
FRAMES_2_TARGET = 8000

# LOAD/SAVE MODELS
LOAD_MODEL = False
MODEL_H5_FILEPATH = "resources/models/breakoutdqn/saved_model_epX_rwY.h5"
SAVE_THRESHOLD = 5


# MISC
REPORT_FILE = False
STEPS_REPORT = 50

env = gym.make('Breakout-v0')
NUM_FEATURES = env.observation_space.shape
NUM_ACTIONS = env.action_space.n
print('Number of state features: {}'.format(NUM_FEATURES))
print('Number of possible actions: {}'.format(NUM_ACTIONS))
print(env.unwrapped.get_action_meanings())
print('Reward Range:', env.reward_range)
print(env.metadata)
print(env.spec)
# Out:
# Number of state features: (210, 160, 3)
# Number of possible actions: 4
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# Reward Range: (-inf, inf)
# {'render.modes': ['human', 'rgb_array']}
# EnvSpec(Breakout-v0)
# A.L.E: Arcade Learning Environment (version +978d2ce)
# [Powered by Stella]

# %%
def create_q_model():
    # Network defined by the Deepmind paper
    inputs = layers.Input(shape=(NUM_FEATURES[0], NUM_FEATURES[1], 1))

    # Convolutions on the frames on the screen
    layer1 = layers.Conv2D(32, 8, strides=4, activation="relu")(inputs)
    layer2 = layers.Conv2D(64, 4, strides=2, activation="relu")(layer1)
    layer3 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer2)

    layer4 = layers.Flatten()(layer3)

    layer5 = layers.Dense(512, activation="relu")(layer4)
    action = layers.Dense(NUM_ACTIONS, activation="linear")(layer5)

    return keras.Model(inputs=inputs, outputs=action)

if LOAD_MODEL:
    model = tf.keras.models.load_model(MODEL_H5_FILEPATH)
    model_target = tf.keras.models.load_model(MODEL_H5_FILEPATH)
else:
    model = create_q_model()
    model_target = create_q_model()

optimizer = keras.optimizers.Adam(LEARNING_RATE)
loss_function = keras.losses.MeanSquaredError()
# Using huber loss for stability
# loss_function = keras.losses.Huber()
# Out:
# 2022-03-02 20:18:18.523131: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/cxb0439/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-03-02 20:18:18.523159: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-02 20:18:18.523180: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (linux-515177): /proc/driver/nvidia/version does not exist
# 2022-03-02 20:18:18.523382: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def select_epsilon_greedy_action(state, epsilon, epsilon_random_frames, frame_count):
    """Take random action with probability epsilon, else take best action."""
    if frame_count < epsilon_random_frames or epsilon > tf.random.uniform((1,)):
        # Take random action
        action = env.action_space.sample()
    else:
        # Predict action Q-values
        # From environment state
        state_tensor = tf.convert_to_tensor(state)
        state_tensor = tf.expand_dims(state_tensor, 0)
        action_probs = model(state_tensor, training=False)
        # Take best action
        action = tf.argmax(action_probs[0]).numpy()
    return action

# %%
# Experience replay buffers
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
last_100_ep_rewards = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 50000
# Number of frames for exploration
epsilon_greedy_frames = 5000000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 100000
# Train the model after 4 actions
update_after_actions = 4
# How often to update the target network
update_target_network = 10000

time_elapsed = time.time()
while True:  # Run until solved
    state = cv2.cvtColor(np.array(env.reset()), cv2.COLOR_BGR2GRAY)
    episode_reward = 0
    
    for timestep in range(1, MAX_STEPS_PER_EPISODE):
        # env.render(); Adding this line would show the attempts
        # of the agent in a pop up window.
        frame_count += 1

        # Use epsilon-greedy for exploration
        action = select_epsilon_greedy_action(state, EXPLORATION_RATIO, epsilon_random_frames, frame_count)

        # Decay probability of taking random action
        EXPLORATION_RATIO -= EXPLORATION_RATIO_INTERVAL / epsilon_greedy_frames
        EXPLORATION_RATIO = max(EXPLORATION_RATIO, E_DECAY_LIMIT)

        # Apply the sampled action in our environment
        state_next, reward, done, info = env.step(action)
        state_next = cv2.cvtColor(np.array(state_next), cv2.COLOR_BGR2GRAY)

        episode_reward += reward

        # Save actions and states in replay buffer
        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        done_history.append(done)
        rewards_history.append(reward)
        state = state_next

        # Update every fourth frame and once batch size is over 32
        if frame_count % update_after_actions == 0 and len(done_history) > BATCH_SIZE:

            # Get indices of samples for replay buffers
            indices = np.random.choice(range(len(done_history)), size=BATCH_SIZE)

            # Using list comprehension to sample from replay buffer
            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = [rewards_history[i] for i in indices]
            action_sample = [action_history[i] for i in indices]
            done_sample = tf.convert_to_tensor(
                [float(done_history[i]) for i in indices]
            )

            # Build the updated Q-values for the sampled future states
            # Use the target model for stability
            future_rewards = model_target.predict(state_next_sample)
            # Q value = reward + discount factor * expected future reward
            updated_q_values = rewards_sample + DISCOUNT_FACTOR * tf.reduce_max(
                future_rewards, axis=1
            )

            # If final frame set the last value to -1
            updated_q_values = updated_q_values * (1 - done_sample) - done_sample

            # Create a mask so we only calculate loss on the updated Q-values
            masks = tf.one_hot(action_sample, NUM_ACTIONS)

            with tf.GradientTape() as tape:
                # Train the model on the states and updated Q-values
                q_values = model(state_sample)

                # Apply the masks to the Q-values to get the Q-value for action taken
                q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                # Calculate loss between new Q-value and old Q-value
                loss = loss_function(updated_q_values, q_action)

            # Backpropagation
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

        if frame_count % update_target_network == 0:
            # update the the target network with new weights
            model_target.set_weights(model.get_weights())
            # Log details
            # template = "running reward: {:.2f} at episode {}, frame count {}"
            # print(template.format(running_reward, episode_count, frame_count))

        # Limit the state and reward history
        if len(rewards_history) > max_memory_length:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]

        if done:
            break

    # Si el modelo supera el umbral, lo guardo y aumento el umbral.
    if episode_reward >= SAVE_THRESHOLD:
        model.save('resources/models/breakoutdqn/saved_model_ep'+str(episode_count)+'_rw'+str(int(episode_reward))+'.h5')
        SAVE_THRESHOLD += 5
        print("\tIn episode {} we archived {} reward, {} is the new threshold to save. Saving model!".format(episode_count, episode_reward, SAVE_THRESHOLD))
        
    
    # Update running reward to check condition for solving
    if len(last_100_ep_rewards) == 100:
        last_100_ep_rewards = last_100_ep_rewards[1:]
    last_100_ep_rewards.append(episode_reward)
    episode_reward_history.append(episode_reward)
    
    if episode_count % STEPS_REPORT == 0:
        print(f'Episode {episode_count}. Epsilon: {EXPLORATION_RATIO:.3f}. 'f'Reward in last 100 episodes: {np.mean(last_100_ep_rewards):.3f}. Info: {info}. Elapsed time: {int(time.time()-time_elapsed)}')
        time_elapsed = time.time()

    episode_count += 1

    if np.mean(last_100_ep_rewards) >  REWARD_TASK_SOLVED:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        break
# Out:
# Episode 0. Epsilon: 1.000. Reward in last 100 episodes: 0.000. Info: {'lives': 0}. Elapsed time: 13
# 	In episode 3 we archived 5.0 reward, 10 is the new threshold to save. Saving model!
# Episode 50. Epsilon: 0.998. Reward in last 100 episodes: 1.294. Info: {'lives': 0}. Elapsed time: 1352
# Episode 100. Epsilon: 0.995. Reward in last 100 episodes: 1.520. Info: {'lives': 0}. Elapsed time: 1436
# Episode 150. Epsilon: 0.993. Reward in last 100 episodes: 1.690. Info: {'lives': 0}. Elapsed time: 1436
# Episode 200. Epsilon: 0.990. Reward in last 100 episodes: 1.490. Info: {'lives': 0}. Elapsed time: 1342
# Episode 250. Epsilon: 0.988. Reward in last 100 episodes: 1.250. Info: {'lives': 0}. Elapsed time: 1333
# Episode 300. Epsilon: 0.986. Reward in last 100 episodes: 1.170. Info: {'lives': 0}. Elapsed time: 1322
# Episode 350. Epsilon: 0.983. Reward in last 100 episodes: 1.250. Info: {'lives': 0}. Elapsed time: 1382
# Episode 400. Epsilon: 0.981. Reward in last 100 episodes: 1.370. Info: {'lives': 0}. Elapsed time: 1401
# Episode 450. Epsilon: 0.978. Reward in last 100 episodes: 1.530. Info: {'lives': 0}. Elapsed time: 1528
# Episode 500. Epsilon: 0.976. Reward in last 100 episodes: 1.500. Info: {'lives': 0}. Elapsed time: 1412
# Episode 4500. Epsilon: 0.787. Reward in last 100 episodes: 1.270. Info: {'lives': 0}. Elapsed time: 1443
# Episode 4550. Epsilon: 0.785. Reward in last 100 episodes: 1.240. Info: {'lives': 0}. Elapsed time: 1354
# Episode 4600. Epsilon: 0.783. Reward in last 100 episodes: 1.220. Info: {'lives': 0}. Elapsed time: 1426
# Episode 4650. Epsilon: 0.780. Reward in last 100 episodes: 1.260. Info: {'lives': 0}. Elapsed time: 1958
# Episode 4700. Epsilon: 0.778. Reward in last 100 episodes: 1.180. Info: {'lives': 0}. Elapsed time: 1637
# Episode 4750. Epsilon: 0.776. Reward in last 100 episodes: 1.140. Info: {'lives': 0}. Elapsed time: 1428
# Episode 4800. Epsilon: 0.773. Reward in last 100 episodes: 1.350. Info: {'lives': 0}. Elapsed time: 1807
# Episode 4850. Epsilon: 0.771. Reward in last 100 episodes: 1.540. Info: {'lives': 0}. Elapsed time: 1814
# Episode 4900. Epsilon: 0.768. Reward in last 100 episodes: 1.450. Info: {'lives': 0}. Elapsed time: 2403
# Episode 4950. Epsilon: 0.766. Reward in last 100 episodes: 1.360. Info: {'lives': 0}. Elapsed time: 2726
# Episode 5000. Epsilon: 0.764. Reward in last 100 episodes: 1.330. Info: {'lives': 0}. Elapsed time: 1429
# Episode 5050. Epsilon: 0.761. Reward in last 100 episodes: 1.300. Info: {'lives': 0}. Elapsed time: 1401
# Episode 5100. Epsilon: 0.759. Reward in last 100 episodes: 1.220. Info: {'lives': 0}. Elapsed time: 1399
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <module>
#      91         loss = loss_function(updated_q_values, q_action)
#      93     # Backpropagation
# ---> 94     grads = tape.gradient(loss, model.trainable_variables)
#      95     optimizer.apply_gradients(zip(grads, model.trainable_variables))
#      97 if frame_count % update_target_network == 0:
#      98     # update the the target network with new weights
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py:1084, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1080 if output_gradients is not None:
#    1081   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1082                       for x in nest.flatten(output_gradients)]
# -> 1084 flat_grad = imperative_grad.imperative_grad(
#    1085     self._tape,
#    1086     flat_targets,
#    1087     flat_sources,
#    1088     output_gradients=output_gradients,
#    1089     sources_raw=flat_sources_raw,
#    1090     unconnected_gradients=unconnected_gradients)
#    1092 if not self._persistent:
#    1093   # Keep track of watched variables before setting tape to None
#    1094   self._watched_variables = self._tape.watched_variables()
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/tensorflow/python/eager/imperative_grad.py:71, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      67 except ValueError:
#      68   raise ValueError(
#      69       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 71 return pywrap_tfe.TFE_Py_TapeGradient(
#      72     tape._tape,  # pylint: disable=protected-access
#      73     target,
#      74     sources,
#      75     output_gradients,
#      76     sources_raw,
#      77     compat.as_str(unconnected_gradients.value))
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py:159, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     157     gradient_name_scope += forward_pass_name_scope + "/"
#     158   with ops.name_scope(gradient_name_scope):
# --> 159     return grad_fn(mock_op, *out_grads)
#     160 else:
#     161   return grad_fn(mock_op, *out_grads)
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/tensorflow/python/ops/math_grad.py:1744, in _MatMulGrad(op, grad)
#    1742 b = math_ops.conj(op.inputs[1])
#    1743 if not t_a and not t_b:
# -> 1744   grad_a = gen_math_ops.mat_mul(grad, b, transpose_b=True)
#    1745   grad_b = gen_math_ops.mat_mul(a, grad, transpose_a=True)
#    1746 elif not t_a and t_b:
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py:6013, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6011 if tld.is_eager:
#    6012   try:
# -> 6013     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6014       _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6015       transpose_b)
#    6016     return _result
#    6017   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (12, 5))

numbers_series = pd.Series(episode_reward_history)

rolling_numbers_series = numbers_series.rolling(20).mean()

plt.plot(episode_reward_history, label="Reward hist")
plt.plot(rolling_numbers_series, label="Rolling hist")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
def show_video():
    mp4list = glob.glob('resources/videos/breakoutdqn/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Video not found")
    

def wrap_env(env):
    env = Monitor(env, './resources/videos/breakoutdqn', force=True)
    return env

# %%
env = wrap_env(gym.make('Breakout-v0', render_mode='rgb_array'))
state = cv2.cvtColor(np.array(env.reset()), cv2.COLOR_BGR2GRAY)
done = False
ep_rew = 0
while not done:
    env.render()
    # state = tf.expand_dims(state, axis=0)
    action = select_epsilon_greedy_action(state, 0, 1, 1)
    state, reward, done, info = env.step(action)
    state = cv2.cvtColor(np.array(state), cv2.COLOR_BGR2GRAY)
    ep_rew += reward
print('Episode reward was {}'.format(ep_rew))
env.close()
show_video()
# Out:
# /home/cxb0439/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/gym/envs/atari/environment.py:255: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <module>
#       6 env.render()
#       7 # state = tf.expand_dims(state, axis=0)
# ----> 8 action = select_epsilon_greedy_action(state, 0, 1, 1)
#       9 state, reward, done, info = env.step(action)
#      10 state = cv2.cvtColor(np.array(state), cv2.COLOR_BGR2GRAY)
#
# Input In [4], in select_epsilon_greedy_action(state, epsilon, epsilon_random_frames, frame_count)
#       9 state_tensor = tf.convert_to_tensor(state)
#      10 state_tensor = tf.expand_dims(state_tensor, 0)
# ---> 11 action_probs = model(state_tensor, training=False)
#      12 # Take best action
#      13 action = tf.argmax(action_probs[0]).numpy()
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/engine/base_layer.py:1083, in Layer.__call__(self, *args, **kwargs)
#    1079   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1081 with autocast_variable.enable_auto_cast_variables(
#    1082     self._compute_dtype_object):
# -> 1083   outputs = call_fn(inputs, *args, **kwargs)
#    1085 if self._activity_regularizer:
#    1086   self._handle_activity_regularization(inputs, outputs)
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/engine/functional.py:451, in Functional.call(self, inputs, training, mask)
#     432 @doc_controls.do_not_doc_inheritable
#     433 def call(self, inputs, training=None, mask=None):
#     434   """Calls the model on new inputs.
#     435
#     436   In this case `call` just reapplies
#    (...)
#     449       a list of tensors if there are more than one outputs.
#     450   """
# --> 451   return self._run_internal_graph(
#     452       inputs, training=training, mask=mask)
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/engine/functional.py:589, in Functional._run_internal_graph(self, inputs, training, mask)
#     586   continue  # Node is not computable, try skipping.
#     588 args, kwargs = node.map_arguments(tensor_dict)
# --> 589 outputs = node.layer(*args, **kwargs)
#     591 # Update tensor_dict.
#     592 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/engine/base_layer.py:1088, in Layer.__call__(self, *args, **kwargs)
#    1086   self._handle_activity_regularization(inputs, outputs)
#    1087 if self._supports_masking:
# -> 1088   self._set_mask_metadata(inputs, outputs, input_masks, not eager)
#    1089 if self._saved_model_inputs_spec is None:
#    1090   self._set_save_spec(inputs, args, kwargs)
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/engine/base_layer.py:2549, in Layer._set_mask_metadata(self, inputs, outputs, previous_mask, build_graph)
#    2543   return
#    2545 flat_outputs = tf.nest.flatten(outputs)
#    2547 mask_already_computed = (
#    2548     getattr(self, '_compute_output_and_mask_jointly', False) or
# -> 2549     all(getattr(x, '_keras_mask', None) is not None for x in flat_outputs))
#    2550 if mask_already_computed:
#    2551   if build_graph:
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/keras/engine/base_layer.py:2549, in <genexpr>(.0)
#    2543   return
#    2545 flat_outputs = tf.nest.flatten(outputs)
#    2547 mask_already_computed = (
#    2548     getattr(self, '_compute_output_and_mask_jointly', False) or
# -> 2549     all(getattr(x, '_keras_mask', None) is not None for x in flat_outputs))
#    2550 if mask_already_computed:
#    2551   if build_graph:
#
# File ~/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:433, in Tensor.__getattr__(self, name)
#     430   self._id = uid()
#     431   self._name = None
# --> 433 def __getattr__(self, name):
#     434   if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     435               "tolist", "data"}:
#     436     # TODO(wangpeng): Export the enable_numpy_behavior knob
#     437     raise AttributeError("""
#     438       '{}' object has no attribute '{}'.
#     439       If you are looking for numpy-related methods, please run the following:
#     440       from tensorflow.python.ops.numpy_ops import np_config
#     441       np_config.enable_numpy_behavior()""".format(type(self).__name__, name))
#
# KeyboardInterrupt:
