# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Mountaincar

# %%
mountaincar_rewards_noattack = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_noattack.csv").sample(200, ignore_index=True)

# %%
mountaincar_rewards_attack_20_pm005 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_attack_20%_+-005.csv")
mountaincar_rewards_defense_20_pm005_01_10 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_20%_+-005_01_10.csv")
mountaincar_rewards_attack_20_pm01 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_attack_20%_+-01.csv")
mountaincar_rewards_defense_20_pm01_01_10 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_20%_+-01_01_10.csv")

mountaincar_rewards_attack_50_pm005 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_attack_50%_+-005.csv")
mountaincar_rewards_defense_50_pm005_01_10 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_50%_+-005_01_10.csv")
mountaincar_rewards_attack_50_pm01 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_attack_50%_+-01.csv")
mountaincar_rewards_defense_50_pm01_01_10 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_50%_+-01_01_10.csv")

mountaincar_rewards_attack_70_pm005 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_attack_70%_+-005.csv")
mountaincar_rewards_defense_70_pm005_01_10 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_70%_+-005_01_10.csv")
mountaincar_rewards_attack_70_pm01 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_attack_70%_+-01.csv")
mountaincar_rewards_defense_70_pm01_01_10 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_70%_+-01_01_10.csv")

mountaincar_rewards_defense_50_pm005_01_2000 = pd.read_csv("../ejecuciones_mountaincar_tfm/mountaincar_reward_defense_50%_+-005_01_2000.csv")

# %% [markdown]
# ### Analisis Non_Freeze con Mountaincar

# %%
mountaincar_rewards_defense_nofreeze = pd.DataFrame()

mountaincar_rewards_defense_nofreeze["rolling_average_noattack"] = mountaincar_rewards_noattack.episode_reward.rolling(50).mean()
mountaincar_rewards_defense_nofreeze["rolling_average_attack_50%_+-005"] = mountaincar_rewards_attack_50_pm005.episode_reward.rolling(50).mean()
mountaincar_rewards_defense_nofreeze["rolling_average_defense_50%_+-005_01_10"] = mountaincar_rewards_defense_50_pm005_01_10.episode_reward.rolling(50).mean()
mountaincar_rewards_defense_nofreeze["rolling_average_defense_50%_+-005_01_2000"] = mountaincar_rewards_defense_50_pm005_01_2000.episode_reward.rolling(50).mean()


mountaincar_rewards_defense_nofreeze.plot(y=["rolling_average_noattack",
                               "rolling_average_attack_50%_+-005",
                               "rolling_average_defense_50%_+-005_01_10",
                               "rolling_average_defense_50%_+-005_01_2000"],
                               kind="line",
                               figsize=(20,10),
                               title="Análisis impacto non_freeze en recompensa 50% +-0,05 Mountaincar",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})

# %% [markdown]
# # Analisis 20%

# %%
mountaincar_rewards_20p = pd.DataFrame()

mountaincar_rewards_20p["rolling_average_noattack"] = mountaincar_rewards_noattack.episode_reward.rolling(100).mean()
mountaincar_rewards_20p["rolling_average_attack_20%_+-005"] = mountaincar_rewards_attack_20_pm005.episode_reward.rolling(100).mean()
mountaincar_rewards_20p["rolling_average_defense_20%_+-005_01_10"] = mountaincar_rewards_defense_20_pm005_01_10.episode_reward.rolling(100).mean()
mountaincar_rewards_20p["rolling_average_attack_20%_+-01"] = mountaincar_rewards_attack_20_pm01.episode_reward.rolling(100).mean()
mountaincar_rewards_20p["rolling_average_defense_20%_+-01_01_10"] = mountaincar_rewards_defense_20_pm01_01_10.episode_reward.rolling(100).mean()


mountaincar_rewards_20p.plot(y=["rolling_average_noattack",
                                "rolling_average_attack_20%_+-005",
                                "rolling_average_defense_20%_+-005_01_10",
                                "rolling_average_attack_20%_+-01",
                                "rolling_average_defense_20%_+-01_01_10"],
                               kind="line",
                               figsize=(20,10),
                               title="Gráfica impacto en recompensa implementación final defensa 20% Mountaincar",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})

# %% [markdown]
# ### Analisis 50%

# %%
mountaincar_rewards_50p = pd.DataFrame()

mountaincar_rewards_50p["rolling_average_noattack"] = mountaincar_rewards_noattack.episode_reward.rolling(50).mean()
mountaincar_rewards_50p["rolling_average_attack_50%_+-005"] = mountaincar_rewards_attack_50_pm005.episode_reward.rolling(50).mean()
mountaincar_rewards_50p["rolling_average_defense_50%_+-005_01_10"] = mountaincar_rewards_defense_50_pm005_01_10.episode_reward.rolling(50).mean()
mountaincar_rewards_50p["rolling_average_attack_50%_+-01"] = mountaincar_rewards_attack_50_pm01.episode_reward.rolling(50).mean()
mountaincar_rewards_50p["rolling_average_defense_50%_+-01_01_10"] = mountaincar_rewards_defense_50_pm01_01_10.episode_reward.rolling(50).mean()


mountaincar_rewards_50p.plot(y=["rolling_average_noattack",
                                "rolling_average_attack_50%_+-005",
                                "rolling_average_defense_50%_+-005_01_10",
                                "rolling_average_attack_50%_+-01",
                                "rolling_average_defense_50%_+-01_01_10"],
                               kind="line",
                               figsize=(20,10),
                               title="Gráfica impacto en recompensa implementación final defensa 50% Mountaincar",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})

# %% [markdown]
# ### Analisis 70%

# %%
mountaincar_rewards_70p = pd.DataFrame()

mountaincar_rewards_70p["rolling_average_noattack"] = mountaincar_rewards_noattack.episode_reward.rolling(50).mean()
mountaincar_rewards_70p["rolling_average_attack_70%_+-005"] = mountaincar_rewards_attack_70_pm005.episode_reward.rolling(50).mean()
mountaincar_rewards_70p["rolling_average_defense_70%_+-005_01_10"] = mountaincar_rewards_defense_70_pm005_01_10.episode_reward.rolling(50).mean()
mountaincar_rewards_70p["rolling_average_attack_70%_+-01"] = mountaincar_rewards_attack_70_pm01.episode_reward.rolling(50).mean()
mountaincar_rewards_70p["rolling_average_defense_70%_+-01_01_10"] = mountaincar_rewards_defense_70_pm01_01_10.episode_reward.rolling(50).mean()


mountaincar_rewards_70p.plot(y=["rolling_average_noattack",
                                "rolling_average_attack_70%_+-005",
                                "rolling_average_defense_70%_+-005_01_10",
                                "rolling_average_attack_70%_+-01",
                                "rolling_average_defense_70%_+-01_01_10"],
                               kind="line",
                               figsize=(20,10),
                               title="Gráfica impacto en recompensa implementación final defensa 70% Mountaincar",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})

# %% [markdown]
# # Cartpole

# %%
cartpole_rewards_noattack = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_noattack.csv").sample(200, ignore_index=True)

# %%
cartpole_rewards_attack_20_pm005 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_attack_20%_+-005.csv")
cartpole_rewards_defense_20_pm005_011_3 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_defense_20%_+-005_011_3.csv")
cartpole_rewards_attack_20_pm01 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_attack_20%_+-01.csv")
cartpole_rewards_defense_20_pm01_011_3 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_defense_20%_+-01_011_3.csv")

cartpole_rewards_attack_50_pm005 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_attack_50%_+-005.csv")
cartpole_rewards_defense_50_pm005_011_3 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_defense_50%_+-005_011_3.csv")
cartpole_rewards_attack_50_pm01 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_attack_50%_+-01.csv")
cartpole_rewards_defense_50_pm01_011_3 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_defense_50%_+-01_011_3.csv")

cartpole_rewards_attack_70_pm005 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_attack_70%_+-005.csv")
cartpole_rewards_defense_70_pm005_011_3 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_defense_70%_+-005_011_3.csv")
cartpole_rewards_attack_70_pm01 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_attack_70%_+-01.csv")
cartpole_rewards_defense_70_pm01_011_3 = pd.read_csv("../ejecuciones_cartpole_tfm/cartpole_reward_defense_70%_+-01_011_3.csv")

# %% [markdown]
# ### Analisis 20%

# %%
cartpole_rewards_20p = pd.DataFrame()

cartpole_rewards_20p["rolling_average_noattack"] = cartpole_rewards_noattack.episode_reward.rolling(50).mean()
cartpole_rewards_20p["rolling_average_attack_20%_+-005"] = cartpole_rewards_attack_20_pm005.episode_reward.rolling(50).mean()
cartpole_rewards_20p["rolling_average_defense_20%_+-005_011_3"] = cartpole_rewards_defense_20_pm005_011_3.episode_reward.rolling(50).mean()
cartpole_rewards_20p["rolling_average_attack_20%_+-01"] = cartpole_rewards_attack_20_pm01.episode_reward.rolling(50).mean()
cartpole_rewards_20p["rolling_average_defense_20%_+-01_011_3"] = cartpole_rewards_defense_20_pm01_011_3.episode_reward.rolling(50).mean()


cartpole_rewards_20p.plot(y=["rolling_average_noattack",
                                "rolling_average_attack_20%_+-005",
                                "rolling_average_defense_20%_+-005_011_3",
                                "rolling_average_attack_20%_+-01",
                                "rolling_average_defense_20%_+-01_011_3"],
                               kind="line",
                               figsize=(20,10),
                               title="Gráfica impacto en recompensa implementación final defensa 20% Cartpole",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})

# %% [markdown]
# ### Analisis 50%

# %%
cartpole_rewards_50p = pd.DataFrame()

cartpole_rewards_50p["rolling_average_noattack"] = cartpole_rewards_noattack.episode_reward.rolling(50).mean()
cartpole_rewards_50p["rolling_average_attack_50%_+-005"] = cartpole_rewards_attack_50_pm005.episode_reward.rolling(50).mean()
cartpole_rewards_50p["rolling_average_defense_50%_+-005_011_3"] = cartpole_rewards_defense_50_pm005_011_3.episode_reward.rolling(50).mean()
cartpole_rewards_50p["rolling_average_attack_50%_+-01"] = cartpole_rewards_attack_50_pm01.episode_reward.rolling(50).mean()
cartpole_rewards_50p["rolling_average_defense_50%_+-01_011_3"] = cartpole_rewards_defense_50_pm01_011_3.episode_reward.rolling(50).mean()


cartpole_rewards_50p.plot(y=[
                                "rolling_average_attack_50%_+-005",
                                "rolling_average_defense_50%_+-005_011_3",
                                "rolling_average_attack_50%_+-01",
                                "rolling_average_defense_50%_+-01_011_3"],
                               kind="line",
                               figsize=(20,10),
                               title="Gráfica impacto en recompensa implementación final defensa 50% Cartpole",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})

# %% [markdown]
# ### Analisis 70%

# %%
cartpole_rewards_70p = pd.DataFrame()

cartpole_rewards_70p["rolling_average_noattack"] = cartpole_rewards_noattack.episode_reward.rolling(50).mean()
cartpole_rewards_70p["rolling_average_attack_70%_+-005"] = cartpole_rewards_attack_70_pm005.episode_reward.rolling(50).mean()
cartpole_rewards_70p["rolling_average_defense_70%_+-005_011_3"] = cartpole_rewards_defense_70_pm005_011_3.episode_reward.rolling(50).mean()
cartpole_rewards_70p["rolling_average_attack_70%_+-01"] = cartpole_rewards_attack_70_pm01.episode_reward.rolling(50).mean()
cartpole_rewards_70p["rolling_average_defense_70%_+-01_011_3"] = cartpole_rewards_defense_70_pm01_011_3.episode_reward.rolling(50).mean()


cartpole_rewards_70p.plot(y=[
                                "rolling_average_attack_70%_+-005",
                                "rolling_average_defense_70%_+-005_011_3",
                                "rolling_average_attack_70%_+-01",
                                "rolling_average_defense_70%_+-01_011_3"],
                               kind="line",
                               figsize=(20,10),
                               title="Gráfica impacto en recompensa implementación final defensa 50% Cartpole",
                               xlabel="Episodios",
                               ylabel="Recompensa")
plt.legend(prop={'size': 15})
