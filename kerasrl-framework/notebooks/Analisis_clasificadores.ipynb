# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
def print_report_from_file(report_filename):
    report_df = pd.read_csv(report_filename)
    print(classification_report(report_df["anomalo"], report_df["pred_anomalo"]))
    conf_mat = confusion_matrix(report_df["anomalo"], report_df["pred_anomalo"])
    fpr, tpr, thresholds = roc_curve(report_df["anomalo"], report_df["pred_anomalo"], pos_label=True)
    roc_auc = auc(fpr, tpr)
    sn.heatmap(conf_mat, annot=True, fmt='g').set_title("Matriz de confusion")
    plt.show()

    plt.title('Curva ROC')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# # Pruebas Mountaincar

# %%
n_reporte = 11
report_filename = "../resultados_clasificadores/mountaincar_classification_"+str(n_reporte)+".csv"
print_report_from_file(report_filename)
# Out:
# /home/cxb0439/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/cxb0439/Documentos/GitHub/openai-gym-dqn/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Mejor clasificador estados anomalos Mountaincar

# %%
n_reporte = 17
report_filename = "../resultados_clasificadores/mountaincar_classification_"+str(n_reporte)+".csv"
print_report_from_file(report_filename)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.51      0.45      0.48      1656
#         True       0.52      0.57      0.54      1700
#
#     accuracy                           0.51      3356
#    macro avg       0.51      0.51      0.51      3356
# weighted avg       0.51      0.51      0.51      3356

# %% [markdown]
# # Pruebas Cartpole

# %%
n_reporte = 3
report_filename = "../resultados_clasificadores/cartpole_classification_"+str(n_reporte)+".csv"
print_report_from_file(report_filename)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.48      0.49      0.49       558
#         True       0.53      0.53      0.53       613
#
#     accuracy                           0.51      1171
#    macro avg       0.51      0.51      0.51      1171
# weighted avg       0.51      0.51      0.51      1171

# %% [markdown]
# # Mejor clasificador estados anomalos Cartpole

# %%
n_reporte = 13
report_filename = "../resultados_clasificadores/cartpole_classification_"+str(n_reporte)+".csv"
print_report_from_file(report_filename)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.50      1.00      0.67     12126
#         True       0.44      0.00      0.01     11954
#
#     accuracy                           0.50     24080
#    macro avg       0.47      0.50      0.34     24080
# weighted avg       0.47      0.50      0.34     24080
